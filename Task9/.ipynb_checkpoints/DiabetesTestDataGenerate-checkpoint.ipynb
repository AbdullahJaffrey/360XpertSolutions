# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df.head(5)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dataset_max_size = 10000

# %%
df['Age(Y)'] = np.random.randint(0,100, dataset_max_size)

# %%
df['BMI(kg/m2)'] = np.random.uniform(0, 70, dataset_max_size)

# %%
df
# Out:
#       Age(Y)  BMI(kg/m2)
# 0         56    3.289128
# 1          8   42.027462
# 2         64   37.710206
# 3         49   69.746457
# 4          7   28.109789
# ...      ...         ...
# 9995      37   51.402417
# 9996      48   52.771672
# 9997      74   13.974619
# 9998      14   49.306361
# 9999      16   43.060576
#
# [10000 rows x 2 columns]

# %%
df['BMIStatus'] = df['BMI(kg/m2)'].apply(lambda x: "Under-weight" if x <= 18.5 else "Normal" if x >= 18.5 and x <= 24.9 else "Over-weight" if x >= 25 and x <= 29.9 else "Moderate-Obese" if x >=30 and x <= 34.9 else "Severely-Obese" if x>= 35 and x < 39.9 else "Morbidly-Obese")

# %%
# 0 => Male and 1 => Female

# %%
df['Gender'] = np.random.choice([0, 1], size=dataset_max_size, p=[0.6, 0.4])

# %%
# 0 => No and 1 => Yes

# %%
df['InheritStatus'] = np.random.choice([0, 1], size=dataset_max_size, p=[0.8, 0.2])

# %%
df.head(5)
# Out:
#    Age(Y)  BMI(kg/m2)       BMIStatus  Gender  InheritStatus
# 0      56    3.289128    Under-weight       1              0
# 1       8   42.027462  Morbidly-Obese       1              0
# 2      64   37.710206  Severely-Obese       0              0
# 3      49   69.746457  Morbidly-Obese       0              0
# 4       7   28.109789     Over-weight       1              0

# %%
df['HbA1c(%)'] =  np.random.uniform(0, 15, dataset_max_size)

# %%
df['HbA1cStatus'] = df['HbA1c(%)'].apply(lambda x: "Non-diabetes" if x<5.7 else "Prediabetes" if x >= 5.7 and x <= 6.4 else "Diabetes" )

# %%
df.sample(5)
# Out:
#       Age(Y)  BMI(kg/m2)       BMIStatus  Gender  InheritStatus   HbA1c(%)  \
# 3738      33   52.320728  Morbidly-Obese       1              0  11.689800
# 4112       3   46.569330  Morbidly-Obese       0              0  13.952134
# 9135      24   51.940770  Morbidly-Obese       0              0  14.151781
# 6322      28   51.384023  Morbidly-Obese       0              0   1.507101
# 5293      79    9.931238    Under-weight       0              0   6.160919
#
#        HbA1cStatus
# 3738      Diabetes
# 4112      Diabetes
# 9135      Diabetes
# 6322  Non-diabetes
# 5293   Prediabetes

# %%
# 0 => No Alzheimer's and 1 => Alzheimer's detected

# %%
df["Alzheimer's"] = np.random.choice([0, 1], size=dataset_max_size, p=[0.92, 0.08])

# %%
df
# Out:
#       Age(Y)  BMI(kg/m2)       BMIStatus  Gender  InheritStatus   HbA1c(%)  \
# 0         56    3.289128    Under-weight       1              0  12.977559
# 1          8   42.027462  Morbidly-Obese       1              0  14.251916
# 2         64   37.710206  Severely-Obese       0              0   1.832511
# 3         49   69.746457  Morbidly-Obese       0              0  12.779523
# 4          7   28.109789     Over-weight       1              0   7.163098
# ...      ...         ...             ...     ...            ...        ...
# 9995      37   51.402417  Morbidly-Obese       0              0   8.376825
# 9996      48   52.771672  Morbidly-Obese       0              0   1.829837
# 9997      74   13.974619    Under-weight       1              1   7.760063
# 9998      14   49.306361  Morbidly-Obese       0              0   0.752810
# 9999      16   43.060576  Morbidly-Obese       1              0   0.827048
#
#        HbA1cStatus  Alzheimer's
# 0         Diabetes            0
# 1         Diabetes            0
# 2     Non-diabetes            0
# 3         Diabetes            1
# 4         Diabetes            1
# ...            ...          ...
# 9995      Diabetes            0
# 9996  Non-diabetes            0
# 9997      Diabetes            0
# 9998  Non-diabetes            0
# 9999  Non-diabetes            0
#
# [10000 rows x 8 columns]

# %%
# 0 => Non Smokers and 1 => Smokers

# %%
df["Smoking"] = np.random.choice([0, 1], size=dataset_max_size, p=[0.50, 0.50])

# %%
df['Cholestrol(mg/dL)'] = np.random.randint(150,300, dataset_max_size)

# %%
df['HDLCholestrol(mg/dL)'] = np.random.randint(40,100, dataset_max_size)

# %%
df['LDLCholestrol(mg/dL)'] = np.random.randint(50,250, dataset_max_size)

# %%
df.head(5)
# Out:
#    Age(Y)  BMI(kg/m2)       BMIStatus  Gender  InheritStatus   HbA1c(%)  \
# 0      56    3.289128    Under-weight       1              0  12.977559
# 1       8   42.027462  Morbidly-Obese       1              0  14.251916
# 2      64   37.710206  Severely-Obese       0              0   1.832511
# 3      49   69.746457  Morbidly-Obese       0              0  12.779523
# 4       7   28.109789     Over-weight       1              0   7.163098
#
#     HbA1cStatus  Alzheimer's  Smoking  Cholestrol(mg/dL)  \
# 0      Diabetes            0        1                173
# 1      Diabetes            0        1                179
# 2  Non-diabetes            0        1                172
# 3      Diabetes            1        1                213
# 4      Diabetes            1        0                192
#
#    HDLCholestrol(mg/dL)  LDLCholestrol(mg/dL)
# 0                    58                   192
# 1                    78                   162
# 2                    56                   205
# 3                    64                   169
# 4                    76                   238

# %%
df['CholestrolStatus'] = df['Cholestrol(mg/dL)'].apply(lambda x: "Heart-Healthy" if x < 200 else 'At-Risk' if x >= 200 and x < 240 else "Dangerous")

# %%
df['LDLCholestrolStatus'] = df['LDLCholestrol(mg/dL)'].apply(lambda x: "Heart-Healthy" if x < 100 else 'At-Risk' if x >= 100 and x < 160 else "Dangerous")

# %%
def hdlcholestrol(row):
    hdl = row['HDLCholestrol(mg/dL)']
    gender = row['Gender']
    
    if gender == 0:
        if hdl >= 40 and hdl <60:
            return "At-Risk"
        elif hdl < 40:
            return "Dangerous"
        else:
            return "Heart-Healthy"
    else:
        if hdl >= 50 and hdl <60:
            return "At-Risk"
        elif hdl < 50:
            return "Dangerous"
        else:
            return "Heart-Healthy"

# %%
df['HDLCholestrolStatus'] = df.apply(hdlcholestrol, axis=1)

# %%
df[:15]
# Out:
#     Age(Y)  BMI(kg/m2)       BMIStatus  Gender  InheritStatus   HbA1c(%)  \
# 0       56    3.289128    Under-weight       1              0  12.977559
# 1        8   42.027462  Morbidly-Obese       1              0  14.251916
# 2       64   37.710206  Severely-Obese       0              0   1.832511
# 3       49   69.746457  Morbidly-Obese       0              0  12.779523
# 4        7   28.109789     Over-weight       1              0   7.163098
# 5       39    9.882324    Under-weight       0              0   2.703627
# 6       55   51.489774  Morbidly-Obese       0              0  10.099819
# 7       73   29.820849     Over-weight       0              0   6.088747
# 8       77   59.443538  Morbidly-Obese       0              0   4.496486
# 9       85   13.535177    Under-weight       0              0  10.064862
# 10      75   35.708489  Severely-Obese       0              1   1.956248
# 11       1   37.712791  Severely-Obese       1              0   1.311105
# 12       4   66.825467  Morbidly-Obese       1              0   0.842624
# 13      49   12.183259    Under-weight       0              0   8.430119
# 14       4   24.888736          Normal       1              0  10.651367
#
#      HbA1cStatus  Alzheimer's  Smoking  Cholestrol(mg/dL)  \
# 0       Diabetes            0        1                173
# 1       Diabetes            0        1                179
# 2   Non-diabetes            0        1                172
# 3       Diabetes            1        1                213
# 4       Diabetes            1        0                192
# 5   Non-diabetes            0        0                286
# 6       Diabetes            1        0                281
# 7    Prediabetes            0        0                227
# 8   Non-diabetes            0        1                171
# 9       Diabetes            0        1                201
# 10  Non-diabetes            0        0                167
# 11  Non-diabetes            0        1                241
# 12  Non-diabetes            0        0                292
# 13      Diabetes            0        0                295
# 14      Diabetes            0        1                231
#
#     HDLCholestrol(mg/dL)  LDLCholestrol(mg/dL) CholestrolStatus  \
# 0                     58                   192    Heart-Healthy
# 1                     78                   162    Heart-Healthy
# 2                     56                   205    Heart-Healthy
# 3                     64                   169          At-Risk
# 4                     76                   238    Heart-Healthy
# 5                     68                   134        Dangerous
# 6                     90                    66        Dangerous
# 7                     74                   197          At-Risk
# 8                     84                   234    Heart-Healthy
# 9                     43                   149          At-Risk
# 10                    97                   213    Heart-Healthy
# 11                    72                   109        Dangerous
# 12                    50                    62        Dangerous
# 13                    90                   187        Dangerous
# 14                    80                   176          At-Risk
#
#    LDLCholestrolStatus HDLCholestrolStatus
# 0            Dangerous             At-Risk
# 1            Dangerous       Heart-Healthy
# 2            Dangerous             At-Risk
# 3            Dangerous       Heart-Healthy
# 4            Dangerous       Heart-Healthy
# 5              At-Risk       Heart-Healthy
# 6        Heart-Healthy       Heart-Healthy
# 7            Dangerous       Heart-Healthy
# 8            Dangerous       Heart-Healthy
# 9              At-Risk             At-Risk
# 10           Dangerous       Heart-Healthy
# 11             At-Risk       Heart-Healthy
# 12       Heart-Healthy             At-Risk
# 13           Dangerous       Heart-Healthy
# 14           Dangerous       Heart-Healthy

# %%
df['RandomGlucose(mg/dL)'] = np.random.uniform(70, 400, dataset_max_size)

# %%
df['SugarBloodLevel'] = df['RandomGlucose(mg/dL)'].apply(lambda x: "Fasting" if x >= 70 and x < 100 else "Impaired-Tolerance" if x >= 100 and x < 140 else "Pre-Diabetes" if x >= 140 and x < 200 else "Diabetes")

# %%
df.head()
# Out:
#    Age(Y)  BMI(kg/m2)       BMIStatus  Gender  InheritStatus   HbA1c(%)  \
# 0      56    3.289128    Under-weight       1              0  12.977559
# 1       8   42.027462  Morbidly-Obese       1              0  14.251916
# 2      64   37.710206  Severely-Obese       0              0   1.832511
# 3      49   69.746457  Morbidly-Obese       0              0  12.779523
# 4       7   28.109789     Over-weight       1              0   7.163098
#
#     HbA1cStatus  Alzheimer's  Smoking  Cholestrol(mg/dL)  \
# 0      Diabetes            0        1                173
# 1      Diabetes            0        1                179
# 2  Non-diabetes            0        1                172
# 3      Diabetes            1        1                213
# 4      Diabetes            1        0                192
#
#    HDLCholestrol(mg/dL)  LDLCholestrol(mg/dL) CholestrolStatus  \
# 0                    58                   192    Heart-Healthy
# 1                    78                   162    Heart-Healthy
# 2                    56                   205    Heart-Healthy
# 3                    64                   169          At-Risk
# 4                    76                   238    Heart-Healthy
#
#   LDLCholestrolStatus HDLCholestrolStatus  RandomGlucose(mg/dL)  \
# 0           Dangerous             At-Risk            206.643879
# 1           Dangerous       Heart-Healthy            325.359299
# 2           Dangerous             At-Risk            159.881874
# 3           Dangerous       Heart-Healthy            150.961596
# 4           Dangerous       Heart-Healthy            240.694213
#
#   SugarBloodLevel
# 0        Diabetes
# 1        Diabetes
# 2    Pre-Diabetes
# 3    Pre-Diabetes
# 4        Diabetes

# %%
df['DiabetesType'] = df.apply(lambda row: 'Type 1' if row['HbA1c(%)'] > 10 or row['RandomGlucose(mg/dL)'] > 200 else ('Type 2' if row['HbA1c(%)'] > 6.5 else 'None'), axis=1)

# %%
# 1 => 'Yes' and 0 => 'No'

# %%
df['InsulinUsage'] = df['DiabetesType'].apply(lambda x: 1 if x == 'Type 1' else 0)

# %%
df['Hypertension'] = df['CholestrolStatus'].apply(lambda x: 1 if x in ['Dangerous', 'At-Risk'] else 0)

# %%
df = df.sample(frac = 1)

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.to_csv('DiabetesTestData.csv', index=False)

# %%
df[:100].to_csv('DiabetesTestData100.csv', index=False)
